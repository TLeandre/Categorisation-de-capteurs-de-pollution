# %% [markdown]
# # <center>Projet ODATA Capteurs de pollution</center>

# %% [markdown]
# **Ribouchon Louison**
# **Tuesta Léandre**
# **FISE 2025**

# %% [markdown]
# # I- Examen des données

# %% [markdown]
# ### Données environnement capteurs

# %%
import pandas as pd 
import numpy as np

# %%
# récupération des données
donnees_env = pd.read_excel('../data/donnees_environnement_capteurs.xlsx')
donnees_env
# Out:
#    INDEX Typologie de la zone         Type de voie  \
# 0     c1          centre ville          Rue droite
# 1     c2          centre ville          Rue droite
# 2     c3          centre ville  Intersection en T
# 3     c4          centre ville  Intersection en T
# 4     c5          centre ville          Rue droite
# ..   ...                   ...                 ...
# 92   c93  zones residentielles          Rue droite
# 93   c94  zones residentielles          Rue droite
# 94   c95  zones residentielles       Rue en pente
# 95   c96  zones residentielles          Rue droite
# 96   c97  zones residentielles          Rue droite
#
#                                       Nombre de voies  \
# 0   Boulevard a 3 voies de circulation et circulat...
# 1   Boulevard a 3 voies de circulation et circulat...
# 2   Boulevard a 3 voies de circulation et circulat...
# 3   Boulevard a 3 voies de circulation et circulat...
# 4   Boulevard a 3 voies de circulation et circulat...
# ..                                                ...
# 92                                      Rue  a 1 voie
# 93               Rue moyenne a 2 voies de circulation
# 94                                      Rue  a 1 voie
# 95               Rue moyenne a 2 voies de circulation
# 96                                   Rue tres etroite
#
#    Distance capteur / voie         Position capteurs  Presence d'arbres   \
# 0                  1 a 2 m   Parking 4 roues et Arbre       Range arbres
# 1                  1 a 2 m            Parking 4 roues       Range arbres
# 2                  1 a 2 m                      Arbre       Range arbres
# 3                  1 a 2 m            Parking 4 roues       Range arbres
# 4                  1 a 2 m   Parking 4 roues et Arbre       Range arbres
# ..                      ...                       ...                ...
# 92                inf a 1 m  Parking 4 roues et Arbre       Range arbres
# 93                      1 m          Parking 4 roues        Range arbres
# 94                inf a 1 m  Parking 4 roues et Arbre       Range arbres
# 95                inf a 1 m  Parking 4 roues et Arbre       Range arbres
# 96                inf a 1 m   Parking 4 roues  et mur       Range arbres
#
#    Feuille d arbres       Morphologie urbaine Hauteur des batiments  \
# 0      NON en hiver   Batiments de deux cotes                   R+2
# 1      NON en hiver   Batiments de deux cotes                   R+1
# 2      NON en hiver   Batiments de deux cotes                   R+1
# 3      NON en hiver   Batiments de deux cotes                   R+1
# 4      NON en hiver   Batiments de deux cotes                   R+2
# ..               ...                      ...                   ...
# 92     NON en hiver   Batiments de deux cotes                   R+3
# 93     NON en hiver   Batiments de deux cotes                   R+4
# 94     Oui en hiver   Batiments de deux cotes                   R+2
# 95     Oui en hiver   Batiments de deux cotes                   R+2
# 96     NON en hiver   Batiments de deux cotes                   R+2
#
#    Distance capteur / batiment                 Particularite  \
# 0                      1 a 2 m           pas de particuarite
# 1                       2 a 4 m               Administration
# 2                      1 a 2 m                           Feu
# 3                      1 a 2 m   Etablissement enseignement
# 4                      1 a 2 m           pas de particuarite
# ..                          ...                          ...
# 92                         1 m                         Hotel
# 93                         1 m                     arret bus
# 94                     1 a 2 m           pas de particuarite
# 95                     1 a 2 m                       Hopital
# 96                     1 a 2 m   Etablissement enseignement
#
#    Trafic Routier/ vehicule leger (TMJA)  Trafic Routier/ poids lourds (TMJA)  \
# 0                                  14185                                  366
# 1                                  14185                                  366
# 2                                  14185                                  366
# 3                                  14185                                  366
# 4                                  14185                                  366
# ..                                   ...                                  ...
# 92                                   800                                    0
# 93                                   800                                    0
# 94                                   800                                    0
# 95                                  7530                                    5
# 96                                   800                                    0
#
#     Trafic Routier/  2 roues (TMJA)  emission moyenne annuelle (kg/maille/an)  \
# 0                               233                                      3242
# 1                               233                                      3242
# 2                               233                                      3242
# 3                               233                                      3242
# 4                               233                                      3242
# ..                              ...                                       ...
# 92                                0                                      2991
# 93                                0                                      2991
# 94                                0                                      2270
# 95                              121                                      2270
# 96                                0                                      2182
#
#     Donnees Cartographie
# 0              32.400002
# 1              32.400002
# 2              26.799999
# 3              37.000000
# 4              27.500000
# ..                   ...
# 92             26.100000
# 93             27.100000
# 94             19.799999
# 95             23.299999
# 96             19.299999
#
# [97 rows x 17 columns]

# %%
donnees_env.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   INDEX                                     97 non-null     object
#  1   Typologie de la zone                      97 non-null     object
#  2   Type de voie                              97 non-null     object
#  3   Nombre de voies                           97 non-null     object
#  4   Distance capteur / voie                   97 non-null     object
#  5   Position capteurs                         97 non-null     object
#  6   Presence d'arbres                         97 non-null     object
#  7   Feuille d arbres                          97 non-null     object
#  8   Morphologie urbaine                       97 non-null     object
#  9   Hauteur des batiments                     97 non-null     object
#  10  Distance capteur / batiment               97 non-null     object
#  11  Particularite                             97 non-null     object
#  12  Trafic Routier/ vehicule leger (TMJA)     97 non-null     object
#  13  Trafic Routier/ poids lourds (TMJA)       97 non-null     int64
#  14  Trafic Routier/  2 roues (TMJA)           97 non-null     int64
#  15  emission moyenne annuelle (kg/maille/an)  97 non-null     int64
#  16  Donnees Cartographie                      97 non-null     float64
# dtypes: float64(1), int64(3), object(13)
# memory usage: 13.0+ KB

# %% [markdown]
# ### Données mesures

# %%
# récupération des données
donnees_mes = pd.read_excel("../data/donnees_mesures_PM2_5.xlsx")
donnees_mes
# Out:
#                      Date     c1        c3        c5     c7     c8    c10  \
# 0     2023-01-01 00:00:00  4.678  4.496000  4.505000  4.607  2.790  4.222
# 1     2023-01-01 00:15:00  4.439       NaN       NaN  4.330  3.167  4.077
# 2     2023-01-01 00:30:00  4.108       NaN       NaN  4.547  3.081  3.871
# 3     2023-01-01 00:45:00  4.713  4.339667  3.982333  4.688    NaN  3.984
# 4     2023-01-01 01:00:00  4.172  3.716000  4.088000    NaN  3.556  3.960
# ...                   ...    ...       ...       ...    ...    ...    ...
# 25779 2023-09-26 12:45:00  1.768  1.892000  1.529000  2.483  1.824    NaN
# 25780 2023-09-26 13:00:00  1.857  1.792000  1.538000  2.548  2.405    NaN
# 25781 2023-09-26 13:15:00  1.939  1.871000  1.953000  2.207  1.761    NaN
# 25782 2023-09-26 13:30:00  1.959       NaN  2.028000  2.415  1.844    NaN
# 25783 2023-09-26 13:45:00  2.904  1.654500  1.713000  2.080  1.593    NaN
#
#          c11    c13    c14  ...    c31     c87    c50    c51      c64    c73  \
# 0      5.668  5.769  4.416  ...  5.810  7.3360  7.312  4.912  27.0110  4.737
# 1      4.423  6.315  5.549  ...  5.732  8.2400  5.480  5.259  30.1920  4.764
# 2      4.744  5.356  4.775  ...  5.611     NaN  7.717  4.599  19.4200  4.922
# 3      5.499  5.329  4.961  ...  5.717  8.4075  4.923  4.927  31.3880  4.721
# 4      4.833  5.613  4.462  ...  5.858  8.7640  4.211  4.539  25.8640  4.651
# ...      ...    ...    ...  ...    ...     ...    ...    ...      ...    ...
# 25779  2.196    NaN  2.567  ...  1.094  2.1650  1.937  3.240   2.2635  5.485
# 25780  2.262    NaN  2.857  ...  1.145  2.1920  2.532  2.328   2.2690  2.182
# 25781  2.056    NaN  2.781  ...  1.520  2.2820  3.054  2.312   2.6060  2.625
# 25782  2.498    NaN  2.914  ...  1.245  2.6810  2.054  3.560   2.1560  2.835
# 25783  2.081    NaN  3.055  ...  1.136  2.7260  1.893    NaN   2.2430  2.400
#
#          c74    c75    c76    c90
# 0      3.080  4.009  7.409  3.918
# 1      3.168  3.999  7.021  4.132
# 2      3.194  4.231    NaN  4.079
# 3      3.517  4.252  6.090  3.876
# 4      3.121  4.141  6.178  3.590
# ...      ...    ...    ...    ...
# 25779    NaN  4.470  2.053  0.762
# 25780    NaN  4.658  2.385  0.639
# 25781    NaN  3.606  2.855  0.769
# 25782    NaN  2.318  3.037  1.560
# 25783    NaN  1.892  2.269  5.893
#
# [25784 rows x 29 columns]

# %%
donnees_mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25784 entries, 0 to 25783
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    25784 non-null  datetime64[ns]
#  1   c1      22679 non-null  float64
#  2   c3      22817 non-null  float64
#  3   c5      22428 non-null  float64
#  4   c7      16003 non-null  float64
#  5   c8      19543 non-null  float64
#  6   c10     22067 non-null  float64
#  7   c11     24340 non-null  float64
#  8   c13     20490 non-null  float64
#  9   c14     23649 non-null  float64
#  10  c19     24106 non-null  float64
#  11  c16     23750 non-null  float64
#  12  c17     23824 non-null  float64
#  13  c22     22418 non-null  float64
#  14  c23     24959 non-null  float64
#  15  c26     13677 non-null  float64
#  16  c27     15008 non-null  float64
#  17  c28     21866 non-null  float64
#  18  c29     22355 non-null  float64
#  19  c31     23020 non-null  float64
#  20  c87     20360 non-null  float64
#  21  c50     23988 non-null  float64
#  22  c51     24173 non-null  float64
#  23  c64     23808 non-null  float64
#  24  c73     23726 non-null  float64
#  25  c74     23811 non-null  float64
#  26  c75     24919 non-null  float64
#  27  c76     20229 non-null  float64
#  28  c90     22615 non-null  float64
# dtypes: datetime64[ns](1), float64(28)
# memory usage: 5.7 MB

# %%
# Compter le nombre de valeurs manquantes par colonne
nombre_na_par_colonne = donnees_mes.isna().sum()
nombre_na_par_colonne
# Out:
# Date        0
# c1       3105
# c3       2967
# c5       3356
# c7       9781
# c8       6241
# c10      3717
# c11      1444
# c13      5294
# c14      2135
# c19      1678
# c16      2034
# c17      1960
# c22      3366
# c23       825
# c26     12107
# c27     10776
# c28      3918
# c29      3429
# c31      2764
# c87      5424
# c50      1796
# c51      1611
# c64      1976
# c73      2058
# c74      1973
# c75       865
# c76      5555
# c90      3169
# dtype: int64

# %%
# Affichage de la distribution des données pour chaque colonne
donnees_mes.hist()
# Out:
# array([[<Axes: title={'center': 'Date'}>, <Axes: title={'center': 'c1'}>,
#         <Axes: title={'center': 'c3'}>, <Axes: title={'center': 'c5'}>,
#         <Axes: title={'center': 'c7'}>],
#        [<Axes: title={'center': 'c8'}>, <Axes: title={'center': 'c10'}>,
#         <Axes: title={'center': 'c11'}>, <Axes: title={'center': 'c13'}>,
#         <Axes: title={'center': 'c14'}>],
#        [<Axes: title={'center': 'c19'}>, <Axes: title={'center': 'c16'}>,
#         <Axes: title={'center': 'c17'}>, <Axes: title={'center': 'c22'}>,
#         <Axes: title={'center': 'c23'}>],
#        [<Axes: title={'center': 'c26'}>, <Axes: title={'center': 'c27'}>,
#         <Axes: title={'center': 'c28'}>, <Axes: title={'center': 'c29'}>,
#         <Axes: title={'center': 'c31'}>],
#        [<Axes: title={'center': 'c87'}>, <Axes: title={'center': 'c50'}>,
#         <Axes: title={'center': 'c51'}>, <Axes: title={'center': 'c64'}>,
#         <Axes: title={'center': 'c73'}>],
#        [<Axes: title={'center': 'c74'}>, <Axes: title={'center': 'c75'}>,
#         <Axes: title={'center': 'c76'}>, <Axes: title={'center': 'c90'}>,
#         <Axes: >]], dtype=object)

# %%
# Affichage des statistiques descriptives
donnees_mes.describe()
# Out:
#                       Date            c1            c3            c5  \
# count                25784  22679.000000  22817.000000  22428.000000
# mean   2023-05-15 06:52:30      4.230878    143.879774      3.759503
# min    2023-01-01 00:00:00      0.101000      0.062000      0.125000
# 25%    2023-03-09 03:26:15      1.826000      2.326000      1.582000
# 50%    2023-05-15 06:52:30      2.940000      4.512000      2.579000
# 75%    2023-07-21 10:18:45      4.781000     21.238000      4.187250
# max    2023-09-26 13:45:00     47.209000   1628.360000    116.258000
# std                    NaN      4.159081    287.764391      4.139841
#
#                  c7            c8           c10           c11           c13  \
# count  16003.000000  19543.000000  22067.000000  24340.000000  20490.000000
# mean       4.727124      3.838585      4.006110      4.762711      5.570949
# min        0.113000      0.087000      0.060000      0.080000      0.087000
# 25%        2.209000      1.731000      1.631000      2.095000      2.232000
# 50%        3.584000      2.742000      2.659000      3.308000      3.671500
# 75%        5.622000      4.515500      4.424500      5.338000      6.194750
# max       47.343000     83.765000     84.358000     51.257000     64.449000
# std        3.957796      3.549323      4.355662      4.607703      5.721227
#
#                 c14  ...           c31           c87           c50  \
# count  23649.000000  ...  23020.000000  20360.000000  23988.000000
# mean       5.424741  ...      4.692523      6.506445      4.472243
# min        0.073000  ...      0.082000      0.237000      0.000000
# 25%        2.238000  ...      1.633000      2.248750      1.866750
# 50%        3.683000  ...      2.774500      4.069000      2.968500
# 75%        6.105000  ...      4.905250      7.468500      4.810250
# max       78.706000  ...    130.536000    261.813000     82.859000
# std        5.483428  ...      6.067209      7.337092      4.764511
#
#                 c51           c64           c73           c74           c75  \
# count  24173.000000  23808.000000  23726.000000  23811.000000  24919.000000
# mean       4.448952     98.214946      4.541791      3.663883      4.899203
# min        0.000000      0.099000      0.087000      0.069000      0.088000
# 25%        1.397000      2.353000      1.914000      1.476000      1.961000
# 50%        2.914000      4.190000      3.108000      2.308000      3.150000
# 75%        5.348000      8.500250      5.125000      3.864000      5.391500
# max      188.449000   2262.048000     77.141000     69.857000    124.285000
# std        5.422009    362.107189      4.479097      4.090825      5.293554
#
#                 c76           c90
# count  20229.000000  22615.000000
# mean       5.384154      3.682320
# min        0.078000      0.060000
# 25%        2.257000      1.307000
# 50%        3.702000      2.202000
# 75%        5.996000      3.869500
# max       46.010000    405.893000
# std        5.343375      7.380765
#
# [8 rows x 29 columns]

# %% [markdown]
# # II- Préprocessing

# %% [markdown]
# ### a) Données environnement capteurs

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##### 1_ Réglage des données mal convertit

# %%
# nouveaux noms des colonnes 
env_colonnes = ['Capteurs',
            'Typologie_zone',
            'Type_voie','Nombre_voies',
            'Distance_capteur_voie',
            'Position_capteurs',
            'Presence_arbres',
            'Feuille_arbres',
            'Morphologie_urbaine',
            'Hauteur_batiments',
            'Distance_capteur_batiment',
            'Particularite',
            'Trafic_Routier_vehicule_leger',
            'Trafic_Routier_poids_lourds',
            'Trafic_Routier_2_roues',
            'emission_moyenne_annuelle_kg_maille_an',
            'Donnees_Cartographie']

# changement des noms de colonne
donnees_env.columns = env_colonnes

#Transformation de la colonne trafic routier vehicule léger en flotant et suppression des caractères inconnus 
donnees_env['Trafic_Routier_vehicule_leger'] = donnees_env['Trafic_Routier_vehicule_leger'].astype(str).replace('\xa0', '').apply(lambda x: float(str(x).replace('\xa0', '')))

# transformation des données des colonnes 12 à 16 en flottant ( afin d'avoir une unicité de type des variables ) 
colonnes_a_convertir = donnees_env.columns[13:16]
donnees_env[colonnes_a_convertir] = donnees_env[colonnes_a_convertir].astype(float)

# %% [markdown]
# ##### 2_ Numérisation des variables qualitatives

# %%
#fonction permettant de transformer les variables qualitatives en variables numériques 
def encodage_ordinal_colonne(df, min, max):
    # Récupération des colonnes à numériser 
    colonnes_a_encoder = df.columns[min:max]
    
    # Création d'un OrdinalEncoder
    ordinal_encoder = OrdinalEncoder()

    # Ajuster l'encodeur aux données et récupérer les catégories ordonnées
    df[colonnes_a_encoder] = ordinal_encoder.fit_transform(df[colonnes_a_encoder])
    
    return df

donnees_env = encodage_ordinal_colonne(donnees_env, 1, 12)
donnees_env
# Out:
#    Capteurs  Typologie_zone  Type_voie  Nombre_voies  Distance_capteur_voie  \
# 0        c1             2.0        3.0           0.0                    0.0
# 1        c2             2.0        3.0           0.0                    0.0
# 2        c3             2.0        0.0           0.0                    0.0
# 3        c4             2.0        0.0           0.0                    0.0
# 4        c5             2.0        3.0           0.0                    0.0
# ..      ...             ...        ...           ...                    ...
# 92      c93             4.0        3.0           2.0                    3.0
# 93      c94             4.0        3.0           3.0                    1.0
# 94      c95             4.0        4.0           2.0                    3.0
# 95      c96             4.0        3.0           3.0                    3.0
# 96      c97             4.0        3.0           5.0                    3.0
#
#     Position_capteurs  Presence_arbres  Feuille_arbres  Morphologie_urbaine  \
# 0                 7.0              2.0             1.0                  1.0
# 1                 4.0              2.0             1.0                  1.0
# 2                 0.0              2.0             1.0                  1.0
# 3                 4.0              2.0             1.0                  1.0
# 4                 7.0              2.0             1.0                  1.0
# ..                ...              ...             ...                  ...
# 92                7.0              2.0             1.0                  1.0
# 93                5.0              2.0             1.0                  1.0
# 94                7.0              2.0             3.0                  1.0
# 95                7.0              2.0             3.0                  1.0
# 96                6.0              2.0             1.0                  1.0
#
#     Hauteur_batiments  Distance_capteur_batiment  Particularite  \
# 0                 3.0                        1.0           11.0
# 1                 2.0                        4.0            1.0
# 2                 2.0                        1.0            4.0
# 3                 2.0                        1.0            3.0
# 4                 3.0                        1.0           11.0
# ..                ...                        ...            ...
# 92                5.0                        3.0            6.0
# 93                0.0                        3.0            9.0
# 94                3.0                        1.0           11.0
# 95                3.0                        1.0            5.0
# 96                3.0                        1.0            3.0
#
#     Trafic_Routier_vehicule_leger  Trafic_Routier_poids_lourds  \
# 0                         14185.0                        366.0
# 1                         14185.0                        366.0
# 2                         14185.0                        366.0
# 3                         14185.0                        366.0
# 4                         14185.0                        366.0
# ..                            ...                          ...
# 92                          800.0                          0.0
# 93                          800.0                          0.0
# 94                          800.0                          0.0
# 95                         7530.0                          5.0
# 96                          800.0                          0.0
#
#     Trafic_Routier_2_roues  emission_moyenne_annuelle_kg_maille_an  \
# 0                    233.0                                  3242.0
# 1                    233.0                                  3242.0
# 2                    233.0                                  3242.0
# 3                    233.0                                  3242.0
# 4                    233.0                                  3242.0
# ..                     ...                                     ...
# 92                     0.0                                  2991.0
# 93                     0.0                                  2991.0
# 94                     0.0                                  2270.0
# 95                   121.0                                  2270.0
# 96                     0.0                                  2182.0
#
#     Donnees_Cartographie
# 0              32.400002
# 1              32.400002
# 2              26.799999
# 3              37.000000
# 4              27.500000
# ..                   ...
# 92             26.100000
# 93             27.100000
# 94             19.799999
# 95             23.299999
# 96             19.299999
#
# [97 rows x 17 columns]

# %%
donnees_env.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Capteurs                                97 non-null     object
#  1   Typologie_zone                          97 non-null     float64
#  2   Type_voie                               97 non-null     float64
#  3   Nombre_voies                            97 non-null     float64
#  4   Distance_capteur_voie                   97 non-null     float64
#  5   Position_capteurs                       97 non-null     float64
#  6   Presence_arbres                         97 non-null     float64
#  7   Feuille_arbres                          97 non-null     float64
#  8   Morphologie_urbaine                     97 non-null     float64
#  9   Hauteur_batiments                       97 non-null     float64
#  10  Distance_capteur_batiment               97 non-null     float64
#  11  Particularite                           97 non-null     float64
#  12  Trafic_Routier_vehicule_leger           97 non-null     float64
#  13  Trafic_Routier_poids_lourds             97 non-null     float64
#  14  Trafic_Routier_2_roues                  97 non-null     float64
#  15  emission_moyenne_annuelle_kg_maille_an  97 non-null     float64
#  16  Donnees_Cartographie                    97 non-null     float64
# dtypes: float64(16), object(1)
# memory usage: 13.0+ KB

# %%
## Suppression de la première colonne ( nom des capteurs ) 
capteurs = donnees_env['Capteurs']
donnees_env = donnees_env.drop(donnees_env.columns[0], axis=1)

# %% [markdown]
# ##### 3_ Normalisation des données

# %%
X = donnees_env.to_numpy()
Y = StandardScaler().fit_transform(X)

donnees_env_normees = pd.DataFrame(Y)
donnees_env_normees.insert(0, "Capteurs", capteurs)
donnees_env_normees.columns = env_colonnes

donnees_env_normees
# Out:
#    Capteurs  Typologie_zone  Type_voie  Nombre_voies  Distance_capteur_voie  \
# 0        c1       -0.517024   0.430795     -1.320749              -1.290219
# 1        c2       -0.517024   0.430795     -1.320749              -1.290219
# 2        c3       -0.517024  -1.934512     -1.320749              -1.290219
# 3        c4       -0.517024  -1.934512     -1.320749              -1.290219
# 4        c5       -0.517024   0.430795     -1.320749              -1.290219
# ..      ...             ...        ...           ...                    ...
# 92      c93        0.958016   0.430795     -0.206726               0.830989
# 93      c94        0.958016   0.430795      0.350286              -0.583150
# 94      c95        0.958016   1.219230     -0.206726               0.830989
# 95      c96        0.958016   0.430795      0.350286               0.830989
# 96      c97        0.958016   0.430795      1.464309               0.830989
#
#     Position_capteurs  Presence_arbres  Feuille_arbres  Morphologie_urbaine  \
# 0            0.877568         0.808421       -0.094694             -0.40209
# 1           -0.573411         0.808421       -0.094694             -0.40209
# 2           -2.508050         0.808421       -0.094694             -0.40209
# 3           -0.573411         0.808421       -0.094694             -0.40209
# 4            0.877568         0.808421       -0.094694             -0.40209
# ..                ...              ...             ...                  ...
# 92           0.877568         0.808421       -0.094694             -0.40209
# 93          -0.089751         0.808421       -0.094694             -0.40209
# 94           0.877568         0.808421        1.742374             -0.40209
# 95           0.877568         0.808421        1.742374             -0.40209
# 96           0.393908         0.808421       -0.094694             -0.40209
#
#     Hauteur_batiments  Distance_capteur_batiment  Particularite  \
# 0           -0.239525                  -0.958066       1.215253
# 1           -0.820374                   0.388781      -1.688184
# 2           -0.820374                  -0.958066      -0.817153
# 3           -0.820374                  -0.958066      -1.107497
# 4           -0.239525                  -0.958066       1.215253
# ..                ...                        ...            ...
# 92           0.922172                  -0.060168      -0.236465
# 93          -1.982071                  -0.060168       0.634566
# 94          -0.239525                  -0.958066       1.215253
# 95          -0.239525                  -0.958066      -0.526809
# 96          -0.239525                  -0.958066      -1.107497
#
#     Trafic_Routier_vehicule_leger  Trafic_Routier_poids_lourds  \
# 0                        1.086158                     1.353421
# 1                        1.086158                     1.353421
# 2                        1.086158                     1.353421
# 3                        1.086158                     1.353421
# 4                        1.086158                     1.353421
# ..                            ...                          ...
# 92                      -0.723478                    -0.717663
# 93                      -0.723478                    -0.717663
# 94                      -0.723478                    -0.717663
# 95                       0.186410                    -0.689370
# 96                      -0.723478                    -0.717663
#
#     Trafic_Routier_2_roues  emission_moyenne_annuelle_kg_maille_an  \
# 0                 1.105770                                0.943359
# 1                 1.105770                                0.943359
# 2                 1.105770                                0.943359
# 3                 1.105770                                0.943359
# 4                 1.105770                                0.943359
# ..                     ...                                     ...
# 92               -0.754825                                0.528258
# 93               -0.754825                                0.528258
# 94               -0.754825                               -0.664124
# 95                0.211407                               -0.664124
# 96               -0.754825                               -0.809658
#
#     Donnees_Cartographie
# 0               1.209708
# 1               1.209708
# 2               0.299326
# 3               1.957521
# 4               0.413124
# ..                   ...
# 92              0.185529
# 93              0.348097
# 94             -0.838650
# 95             -0.269662
# 96             -0.919935
#
# [97 rows x 17 columns]

# %% [markdown]
# ### b) Données mesures

# %%
date = donnees_mes['Date']
donnees_mes = donnees_mes.drop(donnees_mes.columns[0], axis=1)

# %% [markdown]
# ##### 1_ Suppression des valeurs aberrantes

# %%
for colonne in donnees_mes.columns:
        if pd.api.types.is_numeric_dtype(donnees_mes[colonne]):
            Q1 = donnees_mes[colonne].quantile(0.25)
            Q3 = donnees_mes[colonne].quantile(0.75)
            IQR = Q3 - Q1
            
            # Détection des valeurs aberrantes
            outliers_mask = (donnees_mes[colonne] < (Q1 - 1.5 * IQR)) | (donnees_mes[colonne] > (Q3 + 1.5 * IQR))
            
            # Remplacement des valeurs aberrantes par NaN
            donnees_mes.loc[outliers_mask, colonne] = np.nan

# %%
donnees_mes.hist()
# Out:
# array([[<Axes: title={'center': 'c1'}>, <Axes: title={'center': 'c3'}>,
#         <Axes: title={'center': 'c5'}>, <Axes: title={'center': 'c7'}>,
#         <Axes: title={'center': 'c8'}>],
#        [<Axes: title={'center': 'c10'}>, <Axes: title={'center': 'c11'}>,
#         <Axes: title={'center': 'c13'}>, <Axes: title={'center': 'c14'}>,
#         <Axes: title={'center': 'c19'}>],
#        [<Axes: title={'center': 'c16'}>, <Axes: title={'center': 'c17'}>,
#         <Axes: title={'center': 'c22'}>, <Axes: title={'center': 'c23'}>,
#         <Axes: title={'center': 'c26'}>],
#        [<Axes: title={'center': 'c27'}>, <Axes: title={'center': 'c28'}>,
#         <Axes: title={'center': 'c29'}>, <Axes: title={'center': 'c31'}>,
#         <Axes: title={'center': 'c87'}>],
#        [<Axes: title={'center': 'c50'}>, <Axes: title={'center': 'c51'}>,
#         <Axes: title={'center': 'c64'}>, <Axes: title={'center': 'c73'}>,
#         <Axes: title={'center': 'c74'}>],
#        [<Axes: title={'center': 'c75'}>, <Axes: title={'center': 'c76'}>,
#         <Axes: title={'center': 'c90'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ##### 2_ Suppression des colonnes avec un pourcentage de valeurs manquantes supérieur à 33%

# %%
colonnes_del = []
for nom_colonne, nombre_na in nombre_na_par_colonne.items():
    if nombre_na / len(donnees_mes) > 0.33:
        colonnes_del.append([nom_colonne,nombre_na*100/len(donnees_mes)])
        donnees_mes = donnees_mes.drop(nom_colonne, axis=1)
colonnes_del
# Out:
# [['c7', 37.93437790878064],
#  ['c26', 46.95547626434998],
#  ['c27', 41.79336022339435]]

# %% [markdown]
# ##### 3_ Remplissage des valeurs manquantes

# %%
# Imputation par échantillonnage
for colonne in donnees_mes.columns:
    valeurs_manquantes = donnees_mes[colonne].isna()
    valeurs_disponibles = donnees_mes[colonne].dropna()
    imputation = np.random.choice(valeurs_disponibles, size=valeurs_manquantes.sum())
    donnees_mes.loc[valeurs_manquantes, colonne] = imputation

# Afficher les colonnes imputées
donnees_mes.hist()
# Out:
# array([[<Axes: title={'center': 'c1'}>, <Axes: title={'center': 'c3'}>,
#         <Axes: title={'center': 'c5'}>, <Axes: title={'center': 'c8'}>,
#         <Axes: title={'center': 'c10'}>],
#        [<Axes: title={'center': 'c11'}>, <Axes: title={'center': 'c13'}>,
#         <Axes: title={'center': 'c14'}>, <Axes: title={'center': 'c19'}>,
#         <Axes: title={'center': 'c16'}>],
#        [<Axes: title={'center': 'c17'}>, <Axes: title={'center': 'c22'}>,
#         <Axes: title={'center': 'c23'}>, <Axes: title={'center': 'c28'}>,
#         <Axes: title={'center': 'c29'}>],
#        [<Axes: title={'center': 'c31'}>, <Axes: title={'center': 'c87'}>,
#         <Axes: title={'center': 'c50'}>, <Axes: title={'center': 'c51'}>,
#         <Axes: title={'center': 'c64'}>],
#        [<Axes: title={'center': 'c73'}>, <Axes: title={'center': 'c74'}>,
#         <Axes: title={'center': 'c75'}>, <Axes: title={'center': 'c76'}>,
#         <Axes: title={'center': 'c90'}>]], dtype=object)

# %% [markdown]
# # III- Visualisation des données

# %% [markdown]
# ### a) ACP

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
capteurs = donnees_env_normees['Capteurs']
donnees_env_normees = donnees_env_normees.drop(donnees_env_normees.columns[0], axis=1)

# transformation du dataframe en tableau np
Y_acp = donnees_env_normees.to_numpy()

pca = PCA(n_components=16)
Z_acp = pca.fit_transform(Y_acp)

plt.figure(figsize=(10, 6))
plt.scatter(Z_acp[:,0], Z_acp[:,1], marker='o')
plt.xlabel('Composante Principale 1')
plt.ylabel('Composante Principale 2')
plt.title('Visualisation ACP 2D')
plt.show()

# %% [markdown]
# ### b) t-SNE

# %%
# transformation du dataframe en tableau np
Y_tsne = donnees_env_normees.to_numpy()

tsne = TSNE(n_components=2, random_state=42)
Z_tsne = tsne.fit_transform(Y_tsne)

plt.figure(figsize=(10, 6))
plt.scatter(Z_tsne[:,0], Z_tsne[:,1], marker='o')
plt.xlabel('Composante Principale 1')
plt.ylabel('Composante Principale 2')
plt.title('Visualisation ACP 2D')
plt.show()

# %% [markdown]
# # IV- Recherche de corrélations

# %%
import seaborn as sns

# %%
donnees_env_normees.corr()
# Out:
#                                         Typologie_zone  Type_voie  \
# Typologie_zone                                1.000000  -0.220877
# Type_voie                                    -0.220877   1.000000
# Nombre_voies                                  0.248868  -0.123736
# Distance_capteur_voie                         0.370505  -0.197064
# Position_capteurs                             0.052886   0.231297
# Presence_arbres                              -0.047574   0.123229
# Feuille_arbres                                0.069767   0.145318
# Morphologie_urbaine                          -0.347928   0.252474
# Hauteur_batiments                             0.207387  -0.029009
# Distance_capteur_batiment                    -0.201783   0.120798
# Particularite                                 0.173556  -0.027930
# Trafic_Routier_vehicule_leger                -0.209963   0.126842
# Trafic_Routier_poids_lourds                  -0.235349   0.152644
# Trafic_Routier_2_roues                       -0.225360   0.129805
# emission_moyenne_annuelle_kg_maille_an        0.053727   0.071804
# Donnees_Cartographie                         -0.101846   0.039661
#
#                                         Nombre_voies  Distance_capteur_voie  \
# Typologie_zone                              0.248868               0.370505
# Type_voie                                  -0.123736              -0.197064
# Nombre_voies                                1.000000               0.192088
# Distance_capteur_voie                       0.192088               1.000000
# Position_capteurs                           0.148088              -0.147529
# Presence_arbres                            -0.147471              -0.382069
# Feuille_arbres                             -0.003752              -0.302956
# Morphologie_urbaine                        -0.195107              -0.234479
# Hauteur_batiments                           0.137270               0.101660
# Distance_capteur_batiment                  -0.118138              -0.123446
# Particularite                               0.256226               0.016604
# Trafic_Routier_vehicule_leger              -0.728442              -0.293408
# Trafic_Routier_poids_lourds                -0.700993              -0.227236
# Trafic_Routier_2_roues                     -0.731524              -0.297856
# emission_moyenne_annuelle_kg_maille_an     -0.307444               0.137896
# Donnees_Cartographie                       -0.488624              -0.048350
#
#                                         Position_capteurs  Presence_arbres  \
# Typologie_zone                                   0.052886        -0.047574
# Type_voie                                        0.231297         0.123229
# Nombre_voies                                     0.148088        -0.147471
# Distance_capteur_voie                           -0.147529        -0.382069
# Position_capteurs                                1.000000         0.308228
# Presence_arbres                                  0.308228         1.000000
# Feuille_arbres                                   0.280040         0.747910
# Morphologie_urbaine                             -0.073903         0.169085
# Hauteur_batiments                                0.172549        -0.012202
# Distance_capteur_batiment                       -0.034501         0.267400
# Particularite                                    0.166979         0.049689
# Trafic_Routier_vehicule_leger                   -0.243835         0.075030
# Trafic_Routier_poids_lourds                     -0.155039         0.064935
# Trafic_Routier_2_roues                          -0.238002         0.078650
# emission_moyenne_annuelle_kg_maille_an          -0.178201        -0.312424
# Donnees_Cartographie                            -0.227337        -0.194273
#
#                                         Feuille_arbres  Morphologie_urbaine  \
# Typologie_zone                                0.069767            -0.347928
# Type_voie                                     0.145318             0.252474
# Nombre_voies                                 -0.003752            -0.195107
# Distance_capteur_voie                        -0.302956            -0.234479
# Position_capteurs                             0.280040            -0.073903
# Presence_arbres                               0.747910             0.169085
# Feuille_arbres                                1.000000             0.126073
# Morphologie_urbaine                           0.126073             1.000000
# Hauteur_batiments                             0.021321            -0.556931
# Distance_capteur_batiment                     0.198364             0.557476
# Particularite                                 0.024348            -0.276683
# Trafic_Routier_vehicule_leger                -0.111425            -0.016390
# Trafic_Routier_poids_lourds                  -0.135904             0.010322
# Trafic_Routier_2_roues                       -0.112689            -0.010161
# emission_moyenne_annuelle_kg_maille_an       -0.371634            -0.307084
# Donnees_Cartographie                         -0.336961            -0.216647
#
#                                         Hauteur_batiments  \
# Typologie_zone                                   0.207387
# Type_voie                                       -0.029009
# Nombre_voies                                     0.137270
# Distance_capteur_voie                            0.101660
# Position_capteurs                                0.172549
# Presence_arbres                                 -0.012202
# Feuille_arbres                                   0.021321
# Morphologie_urbaine                             -0.556931
# Hauteur_batiments                                1.000000
# Distance_capteur_batiment                       -0.194532
# Particularite                                    0.134608
# Trafic_Routier_vehicule_leger                   -0.116751
# Trafic_Routier_poids_lourds                     -0.115277
# Trafic_Routier_2_roues                          -0.123036
# emission_moyenne_annuelle_kg_maille_an           0.270166
# Donnees_Cartographie                             0.032952
#
#                                         Distance_capteur_batiment  \
# Typologie_zone                                          -0.201783
# Type_voie                                                0.120798
# Nombre_voies                                            -0.118138
# Distance_capteur_voie                                   -0.123446
# Position_capteurs                                       -0.034501
# Presence_arbres                                          0.267400
# Feuille_arbres                                           0.198364
# Morphologie_urbaine                                      0.557476
# Hauteur_batiments                                       -0.194532
# Distance_capteur_batiment                                1.000000
# Particularite                                           -0.239988
# Trafic_Routier_vehicule_leger                           -0.091284
# Trafic_Routier_poids_lourds                              0.036386
# Trafic_Routier_2_roues                                  -0.081452
# emission_moyenne_annuelle_kg_maille_an                  -0.293546
# Donnees_Cartographie                                    -0.191614
#
#                                         Particularite  \
# Typologie_zone                               0.173556
# Type_voie                                   -0.027930
# Nombre_voies                                 0.256226
# Distance_capteur_voie                        0.016604
# Position_capteurs                            0.166979
# Presence_arbres                              0.049689
# Feuille_arbres                               0.024348
# Morphologie_urbaine                         -0.276683
# Hauteur_batiments                            0.134608
# Distance_capteur_batiment                   -0.239988
# Particularite                                1.000000
# Trafic_Routier_vehicule_leger               -0.104582
# Trafic_Routier_poids_lourds                 -0.136843
# Trafic_Routier_2_roues                      -0.101047
# emission_moyenne_annuelle_kg_maille_an      -0.079003
# Donnees_Cartographie                        -0.023086
#
#                                         Trafic_Routier_vehicule_leger  \
# Typologie_zone                                              -0.209963
# Type_voie                                                    0.126842
# Nombre_voies                                                -0.728442
# Distance_capteur_voie                                       -0.293408
# Position_capteurs                                           -0.243835
# Presence_arbres                                              0.075030
# Feuille_arbres                                              -0.111425
# Morphologie_urbaine                                         -0.016390
# Hauteur_batiments                                           -0.116751
# Distance_capteur_batiment                                   -0.091284
# Particularite                                               -0.104582
# Trafic_Routier_vehicule_leger                                1.000000
# Trafic_Routier_poids_lourds                                  0.871455
# Trafic_Routier_2_roues                                       0.999103
# emission_moyenne_annuelle_kg_maille_an                       0.294361
# Donnees_Cartographie                                         0.680300
#
#                                         Trafic_Routier_poids_lourds  \
# Typologie_zone                                            -0.235349
# Type_voie                                                  0.152644
# Nombre_voies                                              -0.700993
# Distance_capteur_voie                                     -0.227236
# Position_capteurs                                         -0.155039
# Presence_arbres                                            0.064935
# Feuille_arbres                                            -0.135904
# Morphologie_urbaine                                        0.010322
# Hauteur_batiments                                         -0.115277
# Distance_capteur_batiment                                  0.036386
# Particularite                                             -0.136843
# Trafic_Routier_vehicule_leger                              0.871455
# Trafic_Routier_poids_lourds                                1.000000
# Trafic_Routier_2_roues                                     0.880015
# emission_moyenne_annuelle_kg_maille_an                     0.310620
# Donnees_Cartographie                                       0.616335
#
#                                         Trafic_Routier_2_roues  \
# Typologie_zone                                       -0.225360
# Type_voie                                             0.129805
# Nombre_voies                                         -0.731524
# Distance_capteur_voie                                -0.297856
# Position_capteurs                                    -0.238002
# Presence_arbres                                       0.078650
# Feuille_arbres                                       -0.112689
# Morphologie_urbaine                                  -0.010161
# Hauteur_batiments                                    -0.123036
# Distance_capteur_batiment                            -0.081452
# Particularite                                        -0.101047
# Trafic_Routier_vehicule_leger                         0.999103
# Trafic_Routier_poids_lourds                           0.880015
# Trafic_Routier_2_roues                                1.000000
# emission_moyenne_annuelle_kg_maille_an                0.290824
# Donnees_Cartographie                                  0.678972
#
#                                         emission_moyenne_annuelle_kg_maille_an  \
# Typologie_zone                                                        0.053727
# Type_voie                                                             0.071804
# Nombre_voies                                                         -0.307444
# Distance_capteur_voie                                                 0.137896
# Position_capteurs                                                    -0.178201
# Presence_arbres                                                      -0.312424
# Feuille_arbres                                                       -0.371634
# Morphologie_urbaine                                                  -0.307084
# Hauteur_batiments                                                     0.270166
# Distance_capteur_batiment                                            -0.293546
# Particularite                                                        -0.079003
# Trafic_Routier_vehicule_leger                                         0.294361
# Trafic_Routier_poids_lourds                                           0.310620
# Trafic_Routier_2_roues                                                0.290824
# emission_moyenne_annuelle_kg_maille_an                                1.000000
# Donnees_Cartographie                                                  0.501979
#
#                                         Donnees_Cartographie
# Typologie_zone                                     -0.101846
# Type_voie                                           0.039661
# Nombre_voies                                       -0.488624
# Distance_capteur_voie                              -0.048350
# Position_capteurs                                  -0.227337
# Presence_arbres                                    -0.194273
# Feuille_arbres                                     -0.336961
# Morphologie_urbaine                                -0.216647
# Hauteur_batiments                                   0.032952
# Distance_capteur_batiment                          -0.191614
# Particularite                                      -0.023086
# Trafic_Routier_vehicule_leger                       0.680300
# Trafic_Routier_poids_lourds                         0.616335
# Trafic_Routier_2_roues                              0.678972
# emission_moyenne_annuelle_kg_maille_an              0.501979
# Donnees_Cartographie                                1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(donnees_env_normees.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
matrice_corr = donnees_env_normees.corr()
matrice_corr_sup = np.triu(matrice_corr, k=1)

# Recherche des variables les plus corrélés positivement
maximum_corr = np.max(matrice_corr_sup)
indice_max = np.unravel_index(np.argmax(matrice_corr_sup), matrice_corr_sup.shape)
ligne_max, colonne_max = indice_max

# Recherche des variables les plus corrélés négativement
indice_min = np.unravel_index(np.argmin(matrice_corr_sup), matrice_corr_sup.shape)
ligne_min, colonne_min = indice_min
minimum_corr = np.min(matrice_corr_sup)

print("Variables les plus corrélés positivement : ")
print(matrice_corr.columns[colonne_max] + " / " + matrice_corr.index[ligne_max]  + " : " + str(maximum_corr))
print("Variables les plus corrélés négativement : ")
print(matrice_corr.columns[colonne_min] + " / " + matrice_corr.index[ligne_min] + " : " + str(minimum_corr))
# Out:
# Variables les plus corrélés positivement :
# Trafic_Routier_2_roues / Trafic_Routier_vehicule_leger : 0.9991026834241685
# Variables les plus corrélés négativement :
# Trafic_Routier_2_roues / Nombre_voies : -0.7315241329192781

# %%
# Obtenir les indices des données les moins corrélées
indice_min = np.unravel_index(np.argmin(np.abs(matrice_corr)), matrice_corr.shape)
ligne_min, colonne_min = indice_min
minimum_corr = np.min(np.abs(matrice_corr))

print(matrice_corr.columns[colonne_min] + " / " + matrice_corr.index[ligne_min] + " : " + str(minimum_corr))
# Out:
# Feuille_arbres / Nombre_voies : 0.0037520200029214235

# %% [markdown]
# # V- Analyse exploratoire des données

# %% [markdown]
# ### a) ACP

# %%
print(pca.explained_variance_ratio_)
x = np.arange(0, len(pca.explained_variance_ratio_), 1)
y = pca.explained_variance_ratio_
plt.bar(x, y)
plt.show()
# Out:
# [2.79206849e-01 1.89389469e-01 1.21158054e-01 7.31152966e-02
#  6.53207906e-02 5.24010400e-02 4.30007014e-02 3.93055934e-02
#  3.13411286e-02 3.09254262e-02 2.33899708e-02 1.81245351e-02
#  1.43619639e-02 1.14167913e-02 7.50622980e-03 3.61605720e-05]

# %%
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# [0.27920685 0.46859632 0.58975437 0.66286967 0.72819046 0.7805915
#  0.8235922  0.86289779 0.89423892 0.92516435 0.94855432 0.96667885
#  0.98104082 0.99245761 0.99996384 1.        ]

# %% [markdown]
# **Part d'inertie** : choisit le nombre d'axe de façon à conserver une certaine part de l'inertie total, cela revient à fixer un seuil de qualité global
#
# **Regle de Kaiser** : On retient que les axes associés aux valeurs propres considérées comme les plus "informatives", donc supérieures à leurs mopyennes I/p
#
# **Eboulis des valeurs propres** : On trace un graphe représentant la décroissance des valeurs propres et on cherche un coude dans le graphe. On retient les axes associées aux valeurs propres situées avant le coude.
#
# 5, 4, 3,

# %%
## ACP sur uniquement 4 composant

# %%
pca = PCA(n_components=4)
Z_acp = pca.fit_transform(Y_acp)

# %% [markdown]
# ##### 1_ Création des cercles de corrélations

# %%
valeurs_propres = pca.explained_variance_ #valeurs propres                                       
vecteurs_propres = pca.components_ #vecteurs propres 

correlations = np.zeros((pca.n_components_, len(env_colonnes)-1))
for i in range(pca.n_components_):
    for y in range(len(env_colonnes)-1): # car on a garder index
        correlations[i,y] = np.sqrt(valeurs_propres[i]) * vecteurs_propres[i, y]

# %%
# Créer une figure avec une grille de sous-graphiques (1 ligne, 2 colonnes)
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

# Tracer le cercle de corrélation pour les composantes 1 et 2
axs[0].add_artist(plt.Circle((0, 0), 1, fill=False, color='b'))
for i in range(len(correlations[0])):
    axs[0].arrow(0, 0, correlations[0, i], correlations[1, i], label=env_colonnes[i])
    axs[0].text(correlations[0, i] * 1.15, correlations[1, i] * 1.15, f"{env_colonnes[i]}", ha='center', va='center')
axs[0].set_xlabel('Axe1')
axs[0].set_ylabel('Axe2')
axs[0].set_xlim(-1, 1)
axs[0].set_ylim(-1, 1)
axs[0].set_title('Cercle des Corrélations Axes 1 et 2')

# Tracer le cercle de corrélation pour les composantes 3 et 4
axs[1].add_artist(plt.Circle((0, 0), 1, fill=False, color='b'))
for i in range(len(correlations[2])):
    axs[1].arrow(0, 0, correlations[2, i], correlations[3, i], label=env_colonnes[i+1])
    axs[1].text(correlations[2, i] * 1.15, correlations[3, i] * 1.15, f"{env_colonnes[i+1]}", ha='center', va='center')
axs[1].set_xlabel('Axe3')
axs[1].set_ylabel('Axe4')
axs[1].set_xlim(-1, 1)
axs[1].set_ylim(-1, 1)
axs[1].set_title('Cercle des Corrélations Axes 3 et 4')

# Ajuster l'espacement entre les sous-graphiques
plt.tight_layout()

# Afficher la figure
plt.show()

# %% [markdown]
# ##### 2_ Projection des capteurs dans le(s) premier(s) plan(s) principal(aux)

# %%
for i in range (len(np.transpose(Z_acp))):
    donnees_1d = np.transpose(Z_acp)[i]
# Créez un graphique 1D avec des points
# Créez un graphique 1D avec des points et un axe
    plt.figure(figsize=(16, 2))  # Réglez la taille du graphique
    plt.scatter(donnees_1d, [0] * len(donnees_1d), marker='o', color='blue', s=15)  # Ajustez la taille des points avec l'argument 's'
    plt.axhline(y=0, color='black', linewidth=0.5)  # Ajoutez un axe horizontal
    plt.xlabel("Axe " + str(i+1))
    plt.yticks([])  # Supprimez les marques de graduation sur l'axe des ordonnées
    plt.xlim(-5,5)
    plt.show()

# %% [markdown]
# # VI- Clustering des données

# %% [markdown]
# ### a) Classification ascendante hiérarchique

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import SpectralClustering
from sklearn.cluster import DBSCAN
import scipy.cluster.hierarchy as SCH

from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt

# %%
algorithms = ["single", "complete", "average", "centroid", "ward"]
threshold = 8  # Le seuil de coupe du dendrogramme

# Boucle sur les algos
for algo in algorithms:
    # Créer une nouvelle figure pour chaque algorithme
    plt.figure(figsize=(5, 5))

    # Effectuer la CAH
    matrice_liaisons = SCH.linkage(Z_acp, method=algo, optimal_ordering=True)

    # Tracer le dendrogramme
    SCH.dendrogram(matrice_liaisons, color_threshold=threshold)

    # Ajouter un titre au dendrogramme
    plt.title(f"Dendrogramme - Algorithme: {algo}")

    # Afficher la figure
    plt.show()

# %%
matrice_liaisons = SCH.linkage(Z_acp, method="ward", optimal_ordering=True)

# Essayer différents nombres de clusters
nombre_clusters = np.arange(5, 15, 0.5)
scores_silhouette = []

for n in nombre_clusters:
    cluster = SCH.fcluster(matrice_liaisons, n, criterion='distance')
    silhouette_avg = silhouette_score(Z_acp, cluster)
    scores_silhouette.append(silhouette_avg)

# Tracer la courbe de silhouette en fonction du nombre de clusters
plt.figure(figsize=(10, 6))
plt.plot(nombre_clusters, scores_silhouette, marker='o')
plt.xlabel('Nombre de Clusters')
plt.ylabel('Score de Silhouette')
plt.title('Score de Silhouette en fonction du Nombre de Clusters')
plt.show()

# %%
#  choix de t = 8 
t=8
matrice_liaisons = SCH.linkage(Z_acp, method="ward", optimal_ordering=True)
labels_CAH = SCH.fcluster(matrice_liaisons, t, criterion='distance')

plt.figure(figsize=(8, 6))
plt.scatter(Z_acp[:,0], Z_acp[:,1], c=labels_CAH, cmap='rainbow')
plt.title('Classification ascendante hiérarchique avec K=8')
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.show()

# %% [markdown]
# ### b) K-means

# %%
inertias = []

for K in range(1, 98):
    kmeans = KMeans(n_clusters=K, init="random", n_init=10)

    # Ajustez le modèle aux données
    kmeans.fit(Z_acp)

    # Obtenez l'inertie de la partition obtenue
    inertia = kmeans.inertia_
    inertias.append(inertia)

# Affichez les résultats
print("Inertie de la partition pour différentes valeurs de K :")
for K, inertia in zip(range(1, 98), inertias):
    print(f"K={K}: Inertie={inertia}")

# Tracez l'inertie en fonction de K
plt.plot(range(1, 98), inertias)
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Inertie en fonction de K')
plt.show()

#K=10 2 tangeantes se coupent
# Out:
# Inertie de la partition pour différentes valeurs de K :
# K=1: Inertie=1028.7737253989949
# K=2: Inertie=654.4915634992117
# K=3: Inertie=466.6938076215729
# K=4: Inertie=364.40001592394634
# K=5: Inertie=304.31940118125885
# K=6: Inertie=272.71084444025496
# K=7: Inertie=232.050723368722
# K=8: Inertie=211.04693679610273
# K=9: Inertie=187.58383460198783
# K=10: Inertie=181.2966579945029
# K=11: Inertie=155.67104764194096
# K=12: Inertie=149.32345057702284
# K=13: Inertie=148.62039894334197
# K=14: Inertie=130.96159841726976
# K=15: Inertie=122.7369132399115
# K=16: Inertie=112.62646014444209
# K=17: Inertie=117.66920591505898
# K=18: Inertie=104.81285794635926
# K=19: Inertie=94.57275722706399
# K=20: Inertie=98.73441887823418
# K=21: Inertie=89.11734616944028
# K=22: Inertie=83.4296041021452
# K=23: Inertie=81.88208292590554
# K=24: Inertie=73.40075087764986
# K=25: Inertie=65.169440572685
# K=26: Inertie=67.73802687230219
# K=27: Inertie=65.47416583659388
# K=28: Inertie=63.2665876715685
# K=29: Inertie=59.66337378367935
# K=30: Inertie=56.986265734316596
# K=31: Inertie=48.04955120965877
# K=32: Inertie=45.81036078752787
# K=33: Inertie=51.113820352052805
# K=34: Inertie=45.30920509811555
# K=35: Inertie=44.60004832259539
# K=36: Inertie=41.63595059459015
# K=37: Inertie=40.4781747365238
# K=38: Inertie=42.523752876958135
# K=39: Inertie=42.29045643913367
# K=40: Inertie=36.54798945150932
# K=41: Inertie=35.464265953729836
# K=42: Inertie=34.69639220343555
# K=43: Inertie=31.62560763143517
# K=44: Inertie=31.971832497341264
# K=45: Inertie=30.332367460475588
# K=46: Inertie=25.560924284230747
# K=47: Inertie=27.5110232452377
# K=48: Inertie=25.91317464703706
# K=49: Inertie=28.032294220398988
# K=50: Inertie=24.40906776710412
# K=51: Inertie=24.149803368160192
# K=52: Inertie=19.19805255596447
# K=53: Inertie=21.44117968976933
# K=54: Inertie=23.836200060147387
# K=55: Inertie=18.479468761537195
# K=56: Inertie=19.261839731313067
# K=57: Inertie=16.813666770120218
# K=58: Inertie=16.052495781422355
# K=59: Inertie=14.05470003351251
# K=60: Inertie=12.999900320384501
# K=61: Inertie=14.099252678115443
# K=62: Inertie=14.677989737058628
# K=63: Inertie=11.174056372220406
# K=64: Inertie=11.104104649467713
# K=65: Inertie=12.03432003923292
# K=66: Inertie=11.477060452047454
# K=67: Inertie=8.185998317353873
# K=68: Inertie=8.431389445461498
# K=69: Inertie=7.225442607336188
# K=70: Inertie=6.743446955635726
# K=71: Inertie=7.478363214106006
# K=72: Inertie=8.544870874005857
# K=73: Inertie=6.65288267993332
# K=74: Inertie=6.871801729392105
# K=75: Inertie=6.101642175431793
# K=76: Inertie=5.20736975221393
# K=77: Inertie=4.489580924870805
# K=78: Inertie=5.2142241827865226
# K=79: Inertie=3.1833516434318208
# K=80: Inertie=3.73234185230029
# K=81: Inertie=3.528441721642823
# K=82: Inertie=3.1018084789932567
# K=83: Inertie=2.1088960974847266
# K=84: Inertie=1.2773984125735827
# K=85: Inertie=1.5195740732522198
# K=86: Inertie=1.3805045419346098
# K=87: Inertie=1.4385690633185546
# K=88: Inertie=1.379920072137289
# K=89: Inertie=0.5824543851254329
# K=90: Inertie=0.6113116577762112
# K=91: Inertie=0.5391036212318961
# K=92: Inertie=0.288525368824494
# K=93: Inertie=0.021140188412006957
# K=94: Inertie=0.0018511926971374068
# K=95: Inertie=4.314083075427408e-31
# K=96: Inertie=1.2695730193400659e-30
# K=97: Inertie=4.437342591868191e-31
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (95) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (95) found smaller than n_clusters (97). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)

# %%
# Effectuez le clustering K-means avec K=10
kmeans = KMeans(n_clusters=10, init="random", n_init=10)
# Obtenez les étiquettes des clusters
kmeans.fit(Z_acp)
labels_km = kmeans.labels_


# Obtenez les centres des clusters
centres_clusters = kmeans.cluster_centers_

# Affichez les clusters en 2D
plt.figure(figsize=(8, 6))
plt.scatter(Z_acp[:, 0], Z_acp[:, 1], c=labels_km, cmap='rainbow')
plt.scatter(centres_clusters[:, 0], centres_clusters[:, 1], c='black', marker='x', s=100, label='Centres de clusters')
plt.title('K-means avec K=10')
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.legend()
plt.show()

# %% [markdown]
# ### c) GaussianMixture

# %%
# Essayer différents nombres de clusters
nombre_clusters = range(1, 20)
bics = []
aics = []

for n in nombre_clusters:
    gmm = GaussianMixture(n_components=n)
    gmm.fit(Z_acp)
    # utilisation du Critère d'information d'Akaike et du Critère d'information bayésien
    bics.append(gmm.bic(Z_acp))
    aics.append(gmm.aic(Z_acp))

# Tracer les courbes BIC et AIC en fonction du nombre de clusters
plt.figure(figsize=(10, 6))
plt.plot(nombre_clusters, bics, marker='o', label='BIC')
plt.plot(nombre_clusters, aics, marker='o', label='AIC')
plt.xlabel('Nombre de Clusters')
plt.ylabel('Critère d\'Information')
plt.title('Critères d\'Information en fonction du Nombre de Clusters')
plt.legend()
plt.show()

# %%
# Essayer différents nombres de clusters
nombre_clusters = range(2, 20)
scores_silhouette = []

for n in nombre_clusters:
    gmm = GaussianMixture(n_components=n)
    labels = gmm.fit_predict(Z_acp)
    silhouette_avg = silhouette_score(Z_acp, labels)
    scores_silhouette.append(silhouette_avg)

# Tracer la courbe de silhouette en fonction du nombre de clusters
plt.figure(figsize=(10, 6))
plt.plot(nombre_clusters, scores_silhouette, marker='o')
plt.xlabel('Nombre de Clusters')
plt.ylabel('Score de Silhouette')
plt.title('Score de Silhouette en fonction du Nombre de Clusters')
plt.show()

# %%
# Effectuez le clustering GaussianMixture avec K=10
gmm = GaussianMixture(n_components=10)
# Obtenez les étiquettes des clusters
labels_gmm = gmm.fit_predict(Z_acp)
centres_clusters_gmm = gmm.means_

# Affichez les clusters en 2D
plt.figure(figsize=(8, 6))
plt.scatter(Z_acp[:, 0], Z_acp[:, 1], c=labels_gmm, cmap='rainbow')
plt.scatter(centres_clusters_gmm[:, 0], centres_clusters_gmm[:, 1], c='black', marker='x', s=100, label='Centres de clusters')
plt.title('GaussianMixture avec K=10')
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.legend()
plt.show()

# %% [markdown]
# ### d) SpectralClustering

# %%
# Essayer différents nombres de clusters
nombre_clusters = range(2, 20)
affinity = ['rbf','nearest_neighbors']

scores_silhouette_rbf = []
scores_silhouette_nn = []

for aff in affinity:
    for n_clusters in nombre_clusters:
        # Créer le modèle Spectral Clustering avec le nombre de clusters actuel
        modele_spectral = SpectralClustering(n_clusters=n_clusters, affinity=aff , random_state=42) 
        
         # Ajuster le modèle aux données
        labels = modele_spectral.fit_predict(Z_acp)
    
       # Calculer le coefficient de silhouette
        silhouette_coefficient = silhouette_score(Z_acp, labels)
        if aff == 'rbf':
            scores_silhouette_rbf.append(silhouette_coefficient)
        else :
            scores_silhouette_nn.append(silhouette_coefficient)
    
        # Afficher le résultat
        print(f"Nombre de clusters : {n_clusters}, Coefficient de silhouette : {silhouette_coefficient}")

# Tracer la courbe de silhouette en fonction du nombre de clusters
plt.figure(figsize=(10, 6))
plt.plot(nombre_clusters, scores_silhouette_rbf, marker='o', label='rbf')
plt.plot(nombre_clusters, scores_silhouette_nn, marker='o', label='nn')
plt.xlabel('Nombre de Clusters')
plt.ylabel('Score de Silhouette')
plt.title('Score de Silhouette en fonction du Nombre de Clusters')
plt.legend()
plt.show()
# Out:
# Nombre de clusters : 2, Coefficient de silhouette : 0.38469094367838036
# Nombre de clusters : 3, Coefficient de silhouette : 0.3625786657432802
# Nombre de clusters : 4, Coefficient de silhouette : 0.3397763539278201
# Nombre de clusters : 5, Coefficient de silhouette : 0.3196189497518705
# Nombre de clusters : 6, Coefficient de silhouette : 0.3476992354806704
# Nombre de clusters : 7, Coefficient de silhouette : 0.32875706763447105
# Nombre de clusters : 8, Coefficient de silhouette : 0.31357976653085184
# Nombre de clusters : 9, Coefficient de silhouette : 0.30708089451796844
# Nombre de clusters : 10, Coefficient de silhouette : 0.3144226986632285
# Nombre de clusters : 11, Coefficient de silhouette : 0.3305354718297165
# Nombre de clusters : 12, Coefficient de silhouette : 0.32973528226050997
# Nombre de clusters : 13, Coefficient de silhouette : 0.3277256898397938
# Nombre de clusters : 14, Coefficient de silhouette : 0.3294760840210806
# Nombre de clusters : 15, Coefficient de silhouette : 0.290361395758444
# Nombre de clusters : 16, Coefficient de silhouette : 0.34003077119271025
# Nombre de clusters : 17, Coefficient de silhouette : 0.34623387434450126
# Nombre de clusters : 18, Coefficient de silhouette : 0.3398708091740411
# Nombre de clusters : 19, Coefficient de silhouette : 0.33681965763555516
# Nombre de clusters : 2, Coefficient de silhouette : 0.38469094367838036
# Nombre de clusters : 3, Coefficient de silhouette : 0.34106473862478615
# Nombre de clusters : 4, Coefficient de silhouette : 0.3495543134736232
# Nombre de clusters : 5, Coefficient de silhouette : 0.3178471134044354
# Nombre de clusters : 6, Coefficient de silhouette : 0.30926615162991206
# Nombre de clusters : 7, Coefficient de silhouette : 0.31252891323918736
# Nombre de clusters : 8, Coefficient de silhouette : 0.3185268412290365
# Nombre de clusters : 9, Coefficient de silhouette : 0.276512207180379
# Nombre de clusters : 10, Coefficient de silhouette : 0.2899675965971712
# Nombre de clusters : 11, Coefficient de silhouette : 0.28723177300850283
# Nombre de clusters : 12, Coefficient de silhouette : 0.3046409038168108
# Nombre de clusters : 13, Coefficient de silhouette : 0.32491230495755064
# Nombre de clusters : 14, Coefficient de silhouette : 0.3081683490327826
# Nombre de clusters : 15, Coefficient de silhouette : 0.31352076182632443
# Nombre de clusters : 16, Coefficient de silhouette : 0.3282494568476479
# Nombre de clusters : 17, Coefficient de silhouette : 0.31902358820293286
# Nombre de clusters : 18, Coefficient de silhouette : 0.2949010740063049
# Nombre de clusters : 19, Coefficient de silhouette : 0.32492343616483554

# %%
# Créer un modèle de Spectral Clustering
# n_clusters : nombre de clusters à former
spectral_clustering = SpectralClustering(n_clusters=9, affinity='nearest_neighbors', random_state=42)

# Obtenez les étiquettes des clusters
labels_SC = spectral_clustering.fit_predict(Z_acp)

# Calculer les centres des clusters (approximation)
centres_clusters_sc = np.array([Z_acp[labels_SC == i].mean(axis=0) for i in range(len(set(labels_SC)))])

# Affichez les clusters en 2D
plt.figure(figsize=(8, 6))
plt.scatter(Z_acp[:, 0], Z_acp[:, 1], c=labels_SC, cmap='rainbow')
plt.scatter(centres_clusters_sc[:, 0], centres_clusters_sc[:, 1], c='black', marker='x', s=100, label='Centres de clusters')
plt.title('Spectral Clustering avec K=10')
plt.legend()
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.show()

# %% [markdown]
# ### e) DBSCAN

# %%
# Faire varier les paramètres eps et min_samples
eps_values = [0.5, 1.0, 1.5, 2.0]
min_samples_values = [5, 10, 15, 20]

# Calculer le coefficient de silhouette pour chaque combinaison de paramètres
for eps in eps_values:
    for min_samples in min_samples_values:
        # Créer le modèle DBSCAN avec les paramètres actuels
        modele_dbscan = DBSCAN(eps=eps, min_samples=min_samples)

        # Ajuster le modèle aux données
        labels = modele_dbscan.fit_predict(Z_acp)

        # Ignorer les clusters formés uniquement de points considérés comme du bruit (-1)
        if len(set(labels)) > 1:
            # Calculer le coefficient de silhouette
            silhouette_coefficient = silhouette_score(Z_acp, labels)

            # Afficher le résultat
            print(f"eps={eps}, min_samples={min_samples}, Coefficient de silhouette : {silhouette_coefficient}")
# Out:
# eps=1.0, min_samples=5, Coefficient de silhouette : -0.11877197224228461
# eps=1.5, min_samples=5, Coefficient de silhouette : 0.20970724295414242
# eps=1.5, min_samples=10, Coefficient de silhouette : 0.11008970862737658
# eps=2.0, min_samples=5, Coefficient de silhouette : 0.20086101394098016
# eps=2.0, min_samples=10, Coefficient de silhouette : 0.27135041071956556
# eps=2.0, min_samples=15, Coefficient de silhouette : 0.18386072324299432
# eps=2.0, min_samples=20, Coefficient de silhouette : 0.0629823416421843

# %%
# Créer un modèle de Spectral Clustering
dbscan = DBSCAN(eps=1.5, min_samples=5)

#Obtenez les étiquettes des clusters
labels_dbs = dbscan.fit_predict(Z_acp)

# Calculer les centres des clusters (approximation)
unique_labels = set(labels_dbs)
centres_clusters_dbscan = np.array([Z_acp[labels_dbs == label].mean(axis=0) for label in unique_labels if label != -1])


# Affichez les clusters en 2D
plt.figure(figsize=(8, 6))

for label in np.unique(labels_dbs):
    indices = labels_dbs == label
    plt.scatter(Z_acp[indices, 0], Z_acp[indices, 1], label=f'Cluster {label}')
plt.scatter(centres_clusters_dbscan[:, 0], centres_clusters_dbscan[:, 1], c='black', marker='x', s=100, label='Centres de clusters')

plt.title('DBSCAN avec K=10')
plt.legend()
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.show()

# %%
algorithms = ["single", "complete", "average", "centroid", "ward"]
threshold = 8  # Le seuil de coupe du dendrogramme

# Boucle sur les algos
for algo in algorithms:
    # Créer une nouvelle figure pour chaque algorithme
    plt.figure(figsize=(5, 5))

    # Effectuer la CAH
    matrice_liaisons = SCH.linkage(Z_tsne, method=algo, optimal_ordering=True)

    # Tracer le dendrogramme
    SCH.dendrogram(matrice_liaisons, color_threshold=threshold)

    # Ajouter un titre au dendrogramme
    plt.title(f"Dendrogramme - Algorithme: {algo}")

    # Afficher la figure
    plt.show()

# %%
matrice_liaisons = SCH.linkage(Z_tsne, method="ward", optimal_ordering=True)

# Essayer différents nombres de clusters
nombre_clusters = np.arange(5, 20, 0.5)
scores_silhouette = []

for n in nombre_clusters:
    cluster = SCH.fcluster(matrice_liaisons, n, criterion='distance')
    silhouette_avg = silhouette_score(Z_tsne, cluster)
    scores_silhouette.append(silhouette_avg)

# Tracer la courbe de silhouette en fonction du nombre de clusters
plt.figure(figsize=(10, 6))
plt.plot(nombre_clusters, scores_silhouette, marker='o')
plt.xlabel('Nombre de Clusters')
plt.ylabel('Score de Silhouette')
plt.title('Score de Silhouette en fonction du Nombre de Clusters')
plt.show()

# %%
#  choix de t = 12
t=12
matrice_liaisons = SCH.linkage(Z_tsne, method="ward", optimal_ordering=True)
labels_CAH = SCH.fcluster(matrice_liaisons, t, criterion='distance')

plt.figure(figsize=(8, 6))
plt.scatter(Z_tsne[:,0], Z_tsne[:,1], c=labels_CAH, cmap='rainbow')
plt.title('Classification ascendante hiérarchique avec K=8')
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.show()

# %%
inertias = []

for K in range(1, 98):
    kmeans = KMeans(n_clusters=K, init="random", n_init=10)

    # Ajustez le modèle aux données
    kmeans.fit(Z_tsne)

    # Obtenez l'inertie de la partition obtenue
    inertia = kmeans.inertia_
    inertias.append(inertia)

# Affichez les résultats
print("Inertie de la partition pour différentes valeurs de K :")
for K, inertia in zip(range(1, 98), inertias):
    print(f"K={K}: Inertie={inertia}")

# Tracez l'inertie en fonction de K
plt.plot(range(1, 98), inertias)
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Inertie en fonction de K')
plt.show()

#K=10 2 tangeantes se coupent
# Out:
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (50) found smaller than n_clusters (51). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (65) found smaller than n_clusters (66). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (76) found smaller than n_clusters (77). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (80) found smaller than n_clusters (81). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (83) found smaller than n_clusters (84). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (95) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\leand\Desktop\Files\Dev\Categorisation-de-capteurs-de-pollution\venv\lib\site-packages\sklearn\base.py:1152: ConvergenceWarning: Number of distinct clusters (95) found smaller than n_clusters (97). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# Inertie de la partition pour différentes valeurs de K :
# K=1: Inertie=2393.056640625
# K=2: Inertie=1208.95751953125
# K=3: Inertie=543.5822143554688
# K=4: Inertie=358.3803405761719
# K=5: Inertie=299.182861328125
# K=6: Inertie=256.80987548828125
# K=7: Inertie=210.47044372558594
# K=8: Inertie=184.20669555664062
# K=9: Inertie=154.8931121826172
# K=10: Inertie=148.13497924804688
# K=11: Inertie=123.51475524902344
# K=12: Inertie=116.14739990234375
# K=13: Inertie=101.72850799560547
# K=14: Inertie=85.38941955566406
# K=15: Inertie=79.66790008544922
# K=16: Inertie=72.09117889404297
# K=17: Inertie=70.19696044921875
# K=18: Inertie=66.50910949707031
# K=19: Inertie=58.668907165527344
# K=20: Inertie=59.8050422668457
# K=21: Inertie=46.46723175048828
# K=22: Inertie=48.03957748413086
# K=23: Inertie=41.22659683227539
# K=24: Inertie=43.518592834472656
# K=25: Inertie=40.277732849121094
# K=26: Inertie=35.22554397583008
# K=27: Inertie=39.70928192138672
# K=28: Inertie=31.653505325317383
# K=29: Inertie=24.62622833251953
# K=30: Inertie=29.446727752685547
# K=31: Inertie=29.458858489990234
# K=32: Inertie=24.717086791992188
# K=33: Inertie=22.870162963867188
# K=34: Inertie=20.065393447875977
# K=35: Inertie=22.114017486572266
# K=36: Inertie=20.202268600463867
# K=37: Inertie=17.04381561279297
# K=38: Inertie=16.085838317871094
# K=39: Inertie=17.361513137817383
# K=40: Inertie=15.768753051757812
# K=41: Inertie=15.74916934967041
# K=42: Inertie=13.59262752532959
# K=43: Inertie=14.464360237121582
# K=44: Inertie=11.983287811279297
# K=45: Inertie=14.069196701049805
# K=46: Inertie=11.1534423828125
# K=47: Inertie=11.793539047241211
# K=48: Inertie=11.09564208984375
# K=49: Inertie=10.619058609008789
# K=50: Inertie=8.172669410705566
# K=51: Inertie=8.85329532623291
# K=52: Inertie=7.733547210693359
# K=53: Inertie=8.121243476867676
# K=54: Inertie=7.348061561584473
# K=55: Inertie=6.0969953536987305
# K=56: Inertie=7.012050151824951
# K=57: Inertie=6.4539475440979
# K=58: Inertie=6.122556686401367
# K=59: Inertie=6.302289962768555
# K=60: Inertie=5.3197832107543945
# K=61: Inertie=6.031509876251221
# K=62: Inertie=3.7702016830444336
# K=63: Inertie=4.34454345703125
# K=64: Inertie=4.374227046966553
# K=65: Inertie=5.092062473297119
# K=66: Inertie=3.582793951034546
# K=67: Inertie=3.6573431491851807
# K=68: Inertie=2.1523525714874268
# K=69: Inertie=3.3706157207489014
# K=70: Inertie=2.581778049468994
# K=71: Inertie=2.9159162044525146
# K=72: Inertie=2.699775218963623
# K=73: Inertie=1.7895405292510986
# K=74: Inertie=1.7681457996368408
# K=75: Inertie=1.7210323810577393
# K=76: Inertie=1.7962849140167236
# K=77: Inertie=1.7980557680130005
# K=78: Inertie=1.4758005142211914
# K=79: Inertie=1.732897400856018
# K=80: Inertie=0.8133671283721924
# K=81: Inertie=0.7919637560844421
# K=82: Inertie=0.426969438791275
# K=83: Inertie=0.8193306922912598
# K=84: Inertie=0.9044535756111145
# K=85: Inertie=0.40795502066612244
# K=86: Inertie=0.4549212157726288
# K=87: Inertie=0.496239572763443
# K=88: Inertie=0.2738971412181854
# K=89: Inertie=0.108848437666893
# K=90: Inertie=0.19427958130836487
# K=91: Inertie=0.08577452600002289
# K=92: Inertie=0.036096714437007904
# K=93: Inertie=0.0009278961224481463
# K=94: Inertie=0.00017545005539432168
# K=95: Inertie=1.3465651704791526e-08
# K=96: Inertie=3.1189181299851043e-06
# K=97: Inertie=2.679441024611151e-08

# %%
# Effectuez le clustering K-means avec K=8
kmeans = KMeans(n_clusters=10, init="random", n_init=8)
# Obtenez les étiquettes des clusters
kmeans.fit(Z_tsne)
labels_km = kmeans.labels_


# Obtenez les centres des clusters
centres_clusters = kmeans.cluster_centers_

# Affichez les clusters en 2D
plt.figure(figsize=(8, 6))
plt.scatter(Z_tsne[:, 0], Z_tsne[:, 1], c=labels_km, cmap='rainbow')
plt.scatter(centres_clusters[:, 0], centres_clusters[:, 1], c='black', marker='x', s=100, label='Centres de clusters')
plt.title('K-means avec K=10')
plt.xlabel('Axe 1')
plt.ylabel('Axe 2')
plt.legend()
plt.show()
